# %% [markdown]
# # WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %%
len(cities)%50+1
# Out:
# 24

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather"
#units = "metric"
units = "imperial"

city_log = []
temp_log = []
rec_nums = []
set_nums = []
city_records = []

# Build partial query URL
query_url = f"{url}?appid={weather_api_key}&units={units}&q="

def cityQuery(city):
    return f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units={units}&q={city}"

record_num = 0
set_num = 0
#for i in range(0,len(cities)%50+1)
for city in cities:
    response = requests.get(query_url + city)
    if(record_num%51==0):
        set_num +=1
        record_num=0
    
    try:
        respjson = response.json()
        temp_log.append(respjson['main']['temp'])
        rec_nums.append(record_num)
        print(f"Processing Record {record_num} of Set {set_num} | {city}")
        record_num +=1
        city_log.append(respjson['name'])
        city_records.append(respjson)
        set_nums.append(set_num)
        
    except:
        print("City not found. Skipping...")
set_num+=1
print("-----------------------------\nData Retrieval Complete \n-----------------------------")
# Out:
# Processing Record 0 of Set 1 | kiwira
# City not found. Skipping...
# Processing Record 1 of Set 1 | husavik
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | leningradskiy
# Processing Record 4 of Set 1 | port macquarie
# Processing Record 5 of Set 1 | san policarpo
# City not found. Skipping...
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | trapani
# City not found. Skipping...
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | chokurdakh
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | golden
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | naron
# Processing Record 17 of Set 1 | xining
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | catamarca
# Processing Record 20 of Set 1 | lima
# Processing Record 21 of Set 1 | savannah
# Processing Record 22 of Set 1 | fairbanks
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | ambon
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | port elizabeth
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | lata
# Processing Record 29 of Set 1 | robe
# Processing Record 30 of Set 1 | swellendam
# Processing Record 31 of Set 1 | koulikoro
# Processing Record 32 of Set 1 | rawson
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | kulhudhuffushi
# Processing Record 36 of Set 1 | port-cartier
# Processing Record 37 of Set 1 | saint-philippe
# Processing Record 38 of Set 1 | laguna
# Processing Record 39 of Set 1 | tura
# Processing Record 40 of Set 1 | mar del plata
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | la ronge
# Processing Record 45 of Set 1 | vaini
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | taraz
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | lodja
# Processing Record 0 of Set 2 | huron
# City not found. Skipping...
# Processing Record 1 of Set 2 | hualmay
# Processing Record 2 of Set 2 | cap malheureux
# Processing Record 3 of Set 2 | saldanha
# Processing Record 4 of Set 2 | saint anthony
# City not found. Skipping...
# Processing Record 5 of Set 2 | karimnagar
# Processing Record 6 of Set 2 | nelson bay
# Processing Record 7 of Set 2 | astana
# Processing Record 8 of Set 2 | jinka
# Processing Record 9 of Set 2 | saskylakh
# Processing Record 10 of Set 2 | ocampo
# Processing Record 11 of Set 2 | cape town
# Processing Record 12 of Set 2 | henties bay
# City not found. Skipping...
# Processing Record 13 of Set 2 | lakes entrance
# Processing Record 14 of Set 2 | brainerd
# Processing Record 15 of Set 2 | santa cruz de la palma
# Processing Record 16 of Set 2 | kuala selangor
# Processing Record 17 of Set 2 | bassila
# Processing Record 18 of Set 2 | taksimo
# Processing Record 19 of Set 2 | tortosa
# Processing Record 20 of Set 2 | altamira
# Processing Record 21 of Set 2 | idaho falls
# Processing Record 22 of Set 2 | coihaique
# Processing Record 23 of Set 2 | ca mau
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | itarema
# Processing Record 26 of Set 2 | sorland
# Processing Record 27 of Set 2 | mnogovershinnyy
# Processing Record 28 of Set 2 | stirion
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | la troncal
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | yellowknife
# City not found. Skipping...
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | kruisfontein
# City not found. Skipping...
# Processing Record 39 of Set 2 | strelice
# Processing Record 40 of Set 2 | turinsk
# Processing Record 41 of Set 2 | taoudenni
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | sitka
# Processing Record 46 of Set 2 | brae
# Processing Record 47 of Set 2 | vaxjo
# Processing Record 48 of Set 2 | port-gentil
# Processing Record 49 of Set 2 | meadow lake
# Processing Record 50 of Set 2 | souillac
# Processing Record 0 of Set 3 | galesong
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | nikolskoye
# Processing Record 3 of Set 3 | geraldton
# Processing Record 4 of Set 3 
# Processing Record 3 of Set 5 | saint george
# Processing Record 4 of Set 5 | bereda
# Processing Record 5 of Set 5 | daugavpils
# Processing Record 6 of Set 5 | abu samrah
# Processing Record 7 of Set 5 | rockland
# Processing Record 8 of Set 5 | grindavik
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | faya
# City not found. Skipping...
# Processing Record 11 of Set 5 | tiksi
# Processing Record 12 of Set 5 | flic en flac
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | san jose
# Processing Record 15 of Set 5 | rundu
# City not found. Skipping...
# Processing Record 16 of Set 5 | vagamo
# Processing Record 17 of Set 5 | norwich
# Processing Record 18 of Set 5 | bilma
# Processing Record 19 of Set 5 | katsuura
# Processing Record 20 of Set 5 | ulundi
# Processing Record 21 of Set 5 | shache
# City not found. Skipping...
# Processing Record 22 of Set 5 | half moon bay
# Processing Record 23 of Set 5 | polunochnoye
# Processing Record 24 of Set 5 | de aar
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | khartoum
# Processing Record 27 of Set 5 | tomatlan
# Processing Record 28 of Set 5 | whitehorse
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | yar-sale
# Processing Record 31 of Set 5 | zakharovo
# Processing Record 32 of Set 5 | hansot
# Processing Record 33 of Set 5 | nyurba
# City not found. Skipping...
# Processing Record 34 of Set 5 | yerbogachen
# Processing Record 35 of Set 5 | port blair
# Processing Record 36 of Set 5 | waingapu
# Processing Record 37 of Set 5 | antofagasta
# Processing Record 38 of Set 5 | lubango
# Processing Record 39 of Set 5 | ponta do sol
# Processing Record 40 of Set 5 | nuevitas
# Processing Record 41 of Set 5 | barrow
# Processing Record 42 of Set 5 | okhotsk
# Processing Record 43 of Set 5 | hirara
# Processing Record 44 of Set 5 | ilebo
# Processing Record 45 of Set 5 | ambilobe
# Processing Record 46 of Set 5 | labuhan
# Processing Record 47 of Set 5 | srednekolymsk
# Processing Record 48 of Set 5 | makokou
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 50 of Set 5 | kaabong
# Processing Record 0 of Set 6 | palotina
# Processing Record 1 of Set 6 | vostok
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | shakawe
# Processing Record 4 of Set 6 | yumen
# Processing Record 5 of Set 6 | udachnyy
# City not found. Skipping...
# Processing Record 6 of Set 6 | waddan
# Processing Record 7 of Set 6 | valdivia
# Processing Record 8 of Set 6 | buala
# City not found. Skipping...
# Processing Record 9 of Set 6 | lazaro cardenas
# Processing Record 10 of Set 6 | houma
# Processing Record 11 of Set 6 | magdalena
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | vikarabad
# Processing Record 14 of Set 6 | abnub
# Processing Record 15 of Set 6 | palauig
# Processing Record 16 of Set 6 | vila do maio
# Processing Record 17 of Set 6 | flinders
# Processing Record 18 of Set 6 | obo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 6 | steinbach
# Processing Record 20 of Set 6 | otavi
# Processing Record 21 of Set 6 | dosso
# Processing Record 22 of Set 6 | sola
# Processing Record 23 of Set 6 | tucuman
# Processing Record 24 of Set 6 | kodiak
# Processing Record 25 of Set 6 | bapatla
# Processing Record 26 of Set 6 | eucaliptus
# Processing Record 27 of Set 6 | prestice
# Processing Record 28 of Set 6 | mount gambier
# Processing Record 29 of Set 6 | alugan
# Processing Record 30 of Set 6 | khani
# Processing Record 31 of Set 6 | segezha
# Processing Record 32 of Set 6 | port hawkesbury
# Processing Record 33 of Set 6 | cockburn town
# Processing Record 34 of Set 6 | verkhnyaya inta
# Processing Record 35 of Set 6 | ulladulla
# Processing Record 36 of Set 6 | san quintin
# Processing Record 37 of Set 6 | kudahuvadhoo
# Processing Record 38 of Set 6 | springbok
# Processing Record 39 of Set 6 | cairns
# Processing Record 40 of Set 6 | moree
# Processing Record 41 of Set 6 | muroto
# Processing Record 42 of Set 6 | newport
# Processing Record 43 of Set 6 | longyearbyen
# Processing Record 44 of Set 6 | tessalit
# Processing Record 45 of Set 6 | tarko-sale
# Processing Record 46 of Set 6 | kotri
# Processing Record 47 of Set 6 | ostrovnoy
# Processing Record 48 of Set 6 | ziro
# Processing Record 49 of Set 6 | shepetivka
# City not found. Skipping...
# Processing Record 50 of Set 6 | davila
# Processing Record 0 of Set 7 | helong
# City not found. Skipping...
# Processing Record 1 of Set 7 | weymouth
# Processing Record 2 of Set 7 | fuyu
# Processing Record 3 of Set 7 | sedona
# Processing Record 4 of Set 7 | ahuimanu
# Processing Record 5 of Set 7 | inhambane
# Processing Record 6 of Set 7 | baghdad
# Processing Record 7 of Set 7 | negombo
# Processing Record 8 of Set 7 | biak
# Processing Record 9 of Set 7 | namibe
# Processing Record 10 of Set 7 | jhawarian
# Processing Record 11 of Set 7 | san rafael
# Processing Record 12 of Set 7 | egvekinot
# Processing Record 13 of Set 7 | mancora
# Processing Record 14 of Set 7 | payakumbuh
# Processing Record 15 of Set 7 | manitouwadge
# Processing Record 16 of Set 7 | sept-iles
# Processing Record 17 of Set 7 | rostovka
# Processing Record 18 of Set 7 | whittlesea
# Processing Record 19 of Set 7 | uni
# City not found. Skipping...
# Processing Record 20 of Set 7 | salou
# Processing Record 21 of Set 7 | iqaluit
# Processing Record 22 of Set 7 | zaqatala
# Processing Record 23 of Set 7 | dakar
# Processing Record 24 of Set 7 | celestun
# City not found. Skipping...
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | bud
# Processing Record 27 of Set 7 | terme
# Processing Record 28 of Set 7 | akureyri
# Processing Record 29 of Set 7 | tubuala
# Processing Record 30 of Set 7 | latur
# Processing Record 31 of Set 7 | manta
# Processing Record 32 of Set 7 | goderich
# Processing Record 33 of Set 7 | tripoli
# Processing Record 34 of Set 7 | la reforma
# Processing Record 35 of Set 7 | severo-kurilsk
# Processing Record 36 of Set 7 | beringovskiy
# Processing Record 37 of Set 7 | yakeshi
# City not found. Skipping...
# Processing Record 38 of Set 7 | koratla
# Processing Record 39 of Set 7 | araouane
# City not found. Skipping...
# Processing Record 40 of Set 7 | broome
# City not found. Skipping...
# Processing Record 41 of Set 7 | naze
# Processing Record 42 of Set 7 | chapais
# Processing Record 43 of Set 7 | montepuez
# Processing Record 44 of Set 7 | manaus
# Processing Record 45 of Set 7 | ahipara
# Processing Record 46 of Set 7 | los llanos de aridane
# City not found. Skipping...
# Processing Record 47 of Set 7 | kabwe
# Processing Record 48 of Set 7 | kouroussa
# Processing Record 49 of Set 7 | constantine
# Processing Record 50 of Set 7 | vila franca do campo
# Processing Record 0 of Set 8 | rio gallegos
# Processing Record 1 of Set 8 | zhezkazgan
# Processing Record 2 of Set 8 | weligama
# Processing Record 20 of Set 9 | muros
# Processing Record 21 of Set 9 | zeewolde
# Processing Record 22 of Set 9 | colac
# Processing Record 23 of Set 9 | korla
# Processing Record 24 of Set 9 | zhuhai
# Processing Record 25 of Set 9 | totma
# Processing Record 26 of Set 9 | kosonsoy
# Processing Record 27 of Set 9 | mamlyutka
# City not found. Skipping...
# Processing Record 28 of Set 9 | ballina
# Processing Record 29 of Set 9 | camopi
# Processing Record 30 of Set 9 | vicuna
# Processing Record 31 of Set 9 | manokwari
# Processing Record 32 of Set 9 | parry sound
# Processing Record 33 of Set 9 | san buenaventura
# Processing Record 34 of Set 9 | salalah
# Processing Record 35 of Set 9 | vihti
# Processing Record 36 of Set 9 | tygda
# Processing Record 37 of Set 9 | mikhaylovka
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | severnyy
# Processing Record 41 of Set 9 | rayong
# Processing Record 42 of Set 9 | qinzhou
# Processing Record 43 of Set 9 | prince rupert
# Processing Record 44 of Set 9 | killybegs
# Processing Record 45 of Set 9 | bonthe
# Processing Record 46 of Set 9 | gat
# Processing Record 47 of Set 9 | danilov
# Processing Record 48 of Set 9 | muli
# Processing Record 49 of Set 9 | samarkand
# Processing Record 50 of Set 9 | huambo
# Processing Record 0 of Set 10 | chernyshevskiy
# Processing Record 1 of Set 10 | necochea
# Processing Record 2 of Set 10 | dunmore town
# Processing Record 3 of Set 10 | mtwara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 10 | neryungri
# Processing Record 5 of Set 10 | nizhniy baskunchak
# Processing Record 6 of Set 10 | mechernich
# Processing Record 7 of Set 10 | dambulla
# City not found. Skipping...
# Processing Record 8 of Set 10 | smoky lake
# Processing Record 9 of Set 10 | havre-saint-pierre
# Processing Record 10 of Set 10 | bethanien
# Processing Record 11 of Set 10 | saint-pierre
# Processing Record 12 of Set 10 | carauari
# Processing Record 13 of Set 10 | ginir
# Processing Record 14 of Set 10 | kijang
# Processing Record 15 of Set 10 | copiapo
# Processing Record 16 of Set 10 | bluefield
# Processing Record 17 of Set 10 | long beach
# Processing Record 18 of Set 10 | peniche
# Processing Record 19 of Set 10 | allapalli
# City not found. Skipping...
# Processing Record 20 of Set 10 | ixtapa
# Processing Record 21 of Set 10 | pocone
# Processing Record 22 of Set 10 | moron
# City not found. Skipping...
# Processing Record 23 of Set 10 | phan thiet
# Processing Record 24 of Set 10 | santo anastacio
# Processing Record 25 of Set 10 | sibolga
# City not found. Skipping...
# Processing Record 26 of Set 10 | pindi gheb
# Processing Record 27 of Set 10 | kharp
# Processing Record 28 of Set 10 | marsaxlokk
# Processing Record 29 of Set 10 | gizo
# City not found. Skipping...
# Processing Record 30 of Set 10 | beyneu
# Processing Record 31 of Set 10 | raisinghnagar
# Processing Record 32 of Set 10 | tiznit
# Processing Record 33 of Set 10 | camabatela
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | ipixuna
# Processing Record 36 of Set 10 | shubarshi
# Processing Record 37 of Set 10 | broken hill
# Processing Record 38 of Set 10 | jega
# Processing Record 39 of Set 10 | erenhot
# Processing Record 40 of Set 10 | hurghada
# Processing Record 41 of Set 10 | honolulu
# Processing Record 42 of Set 10 | loudon
# Processing Record 43 of Set 10 | verkhnevilyuysk
# Processing Record 44 of Set 10 | tual
# City not found. Skipping...
# Processing Record 45 of Set 10 | orocue
# Processing Record 46 of Set 10 | gevrai
# Processing Record 47 of Set 10 | pare
# City not found. Skipping...
# Processing Record 48 of Set 10 | chengde
# Processing Record 49 of Set 10 | luanda
# Processing Record 50 of Set 10 | haines junction
# Processing Record 0 of Set 11 | varkaus
# Processing Record 1 of Set 11 | graaff-reinet
# Processing Record 2 of Set 11 | manbij
# Processing Record 3 of Set 11 | nioro
# Processing Record 4 of Set 11 | markova
# City not found. Skipping...
# Processing Record 5 of Set 11 | salym
# City not found. Skipping...
# Processing Record 6 of Set 11 | agadez
# Processing Record 7 of Set 11 | fidenza
# Processing Record 8 of Set 11 | kestel
# Processing Record 9 of Set 11 | sabang
# Processing Record 10 of Set 11 | duncan
# Processing Record 11 of Set 11 | humberto de campos
# Processing Record 12 of Set 11 | beloha
# Processing Record 13 of Set 11 | shitanjing
# Processing Record 14 of Set 11 | szczytno
# Processing Record 15 of Set 11 | rio cuarto
# Processing Record 16 of Set 11 | visby
# Processing Record 17 of Set 11 | moba
# Processing Record 18 of Set 11 | vestmannaeyjar
# Processing Record 19 of Set 11 | ivanivka
# Processing Record 20 of Set 11 | vogan
# Processing Record 21 of Set 11 | wooster
# Processing Record 22 of Set 11 | ha tinh
# Processing Record 23 of Set 11 | lake havasu city
# Processing Record 24 of Set 11 | muisne
# Processing Record 25 of Set 11 | cauquenes
# Processing Record 26 of Set 11 | basco
# Processing Record 27 of Set 11 | grand gaube
# Processing Record 28 of Set 11 | kaputa
# Processing Record 29 of Set 11 | porto novo
# Processing Record 30 of Set 11 | graham
# Processing Record 31 of Set 11 | xingyi
# Processing Record 32 of Set 11 | nemuro
# Processing Record 33 of Set 11 | umm kaddadah
# Processing Record 34 of Set 11 | trincomalee
# Processing Record 35 of Set 11 | vuktyl
# Processing Record 36 of Set 11 | turayf
# Processing Record 37 of Set 11 | aksu
# Processing Record 38 of Set 11 | tiszafured
# City not found. Skipping...
# Processing Record 39 of Set 11 | limon
# Processing Record 40 of Set 11 | acarau
# Processing Record 41 of Set 11 | ucluelet
# Processing Record 42 of Set 11 | sinegorye
# Processing Record 43 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 11 | buri
# City not found. Skipping...
# Processing Record 45 of Set 11 | angoche
# Processing Record 46 of Set 11 | lichuan
# Processing Record 47 of Set 11 | capaci
# Processing Record 48 of Set 11 | inuvik
# Processing Record 49 of Set 11 | kamloops
# Processing Record 50 of Set 11 | puerto madryn
# Processing Record 0 of Set 12 | dire dawa
# Processing Record 1 of Set 12 | wilmington
# Processing Record 2 of Set 12 | sosnogorsk
# Processing Record 3 of Set 12 | san cristobal
# Processing Record 4 of Set 12 | isla vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
myDict = {"City":city_log,
          "Temperature":temp_log,
         "Record":city_records,
         "Set Number":set_nums,
         "Record Number":rec_nums}

#myDict = {"City":city_log,
#          "Set": set_nums
#          "Record": rec_nums
#          "Temperature":temp_log}

df = pd.DataFrame(myDict)
df.to_csv("city_weather_df")

# %%
df['Record']
# Out:
# 0      {'coord': {'lon': 33.53, 'lat': -9.17}, 'weath...
# 1      {'coord': {'lon': -17.34, 'lat': 66.04}, 'weat...
# 2      {'coord': {'lon': -68.3, 'lat': -54.8}, 'weath...
# 3      {'coord': {'lon': 178.42, 'lat': 69.38}, 'weat...
# 4      {'coord': {'lon': 152.92, 'lat': -31.43}, 'wea...
#                              ...
# 561    {'coord': {'lon': 41.87, 'lat': 9.59}, 'weathe...
# 562    {'coord': {'lon': -77.94, 'lat': 34.23}, 'weat...
# 563    {'coord': {'lon': 53.88, 'lat': 63.6}, 'weathe...
# 564    {'coord': {'lon': -72.22, 'lat': 7.77}, 'weath...
# 565    {'coord': {'lon': -119.86, 'lat': 34.41}, 'wea...
# Name: Record, Length: 566, dtype: object

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
temp_max = []
wind_speed = []
temperature =[]
for i in range(len(df['Record'])):
    name.append(df['Record'][i]['name'])
    cloudiness.append(df['Record'][i]['clouds']['all'])
    country.append(df['Record'][i]['sys']['country'])
    date.append(df['Record'][i]['dt'])
    humidity.append(df['Record'][i]['main']['humidity'])
    lat.append(df['Record'][i]['coord']['lat'])
    lng.append(df['Record'][i]['coord']['lon'])
    temp_max.append(df['Record'][i]['main']['temp_max'])
    wind_speed.append(df['Record'][i]['wind']['speed'])
    temperature.append(df['Record'][i]['main']['temp'])

# %%
weatherDict = {"City":name,
              "Cloudiness":cloudiness,
               "Country": country,
              "Date":date,
              "Humidity":humidity,
              "Lat":lat,
              "Lng":lng,
              "Max Temp":temp_max,
              "Wind Speed":wind_speed,
               "Temperature": temperature
              }
weather_df = pd.DataFrame(weatherDict)

#Export the city data into a .csv.
weather_df.to_csv("../output_data/cities_weather.csv", index = False, header = True)

#Display the DataFrame
weather_df.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0          Kiwira         100      TZ  1585686885        60  -9.17   33.53
# 1         Husavik          75      IS  1585686885        48  66.04  -17.34
# 2         Ushuaia          40      AR  1585686885        66 -54.80  -68.30
# 3   Leningradskiy          13      RU  1585686886        91  69.38  178.42
# 4  Port Macquarie          18      AU  1585686795       100 -31.43  152.92
#
#    Max Temp  Wind Speed  Temperature
# 0     66.09        2.62        66.09
# 1     42.80       33.33        42.80
# 2     50.00       11.41        50.00
# 3      7.57        5.39         7.57
# 4     62.60        3.36        61.77

# %%
weather_df.count()
# Out:
# City           566
# Cloudiness     566
# Country        566
# Date           566
# Humidity       566
# Lat            566
# Lng            566
# Max Temp       566
# Wind Speed     566
# Temperature    566
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot('Lat','Temperature', kind ='scatter', marker='x')

plt.ylabel("Temperature (C)")
plt.xlabel("Latitute")
plt.title("City Latitude vs. Max Temperature (03/31/20)")
plt.savefig("../output_data/figure1.png")
plt.grid
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot('Lat','Humidity',kind = 'scatter', marker='x')
plt.ylabel("Humidity (%)")
plt.xlabel("Latitute")
plt.title("City Latitude vs. Humidity (03/31/20)")
plt.savefig("../output_data/figure2.png")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot('Lat','Cloudiness',kind = 'scatter', marker='x')

plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitute")
plt.title("City Latitude vs. Cloudiness (03/31/20)")
plt.savefig("../output_data/figure3.png")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot('Lat','Wind Speed',kind = 'scatter', marker='x')

plt.ylabel("Wind Speed (kph)")
plt.xlabel("Latitute")
plt.title("City Latitude vs. Wind Speed (03/31/20)")
plt.savefig("../output_data/figure4.png")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
#function to create Linear Regression plots
def linearRegression(x_values, y_values):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(x_values,y_values, marker='x')
    plt.plot(x_values,regress_values,"r-")
    plt.grid()
    
    if slope>0:
        x = x_values.max()-35
        y = y_values.min()+1
    else:
        x = x_values.min()
        y = y_values.min()+1
      
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")
   
    print(f"The r-squared is: {rvalue}")

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df[weather_df['Lat']>0]
southern_hemisphere = weather_df[weather_df['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(northern_hemisphere['Lat'],northern_hemisphere['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemisphere:\n Max Temp vs. Latitude Linear Regression (03/31/20)")
plt.savefig("../output_data/figure5.png")
plt.show()
# Out:
# The r-squared is: -0.9092693386619276

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
linearRegression(southern_hemisphere['Lat'],southern_hemisphere['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere:\n Max Temp vs. Latitude Linear Regression (03/31/20)")
plt.savefig("../output_data/figure6.png")

plt.show()
# Out:
# The r-squared is: 0.6739594936923147

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(northern_hemisphere['Lat'],northern_hemisphere['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Northern Hemisphere:\n Humidity vs. Latitude Linear Regression (03/31/20)")
plt.ylim(0,100)
plt.savefig("../output_data/figure7.png")
plt.show()
# Out:
# The r-squared is: 0.27689914381476416

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
linearRegression(southern_hemisphere['Lat'],southern_hemisphere['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Southern Hemisphere:\n Humidity vs. Latitude Linear Regression (03/31/20)")
plt.ylim(0,100.1)
plt.savefig("../output_data/figure8.png")
plt.show()
# Out:
# The r-squared is: 0.16511857471787

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(northern_hemisphere['Lat'],northern_hemisphere['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Northern Hemisphere:\n Cloudiness vs. Latitude Linear Regression (03/31/20)")
plt.ylim(0,100)
plt.savefig("../output_data/figure9.png")
plt.show()
# Out:
# The r-squared is: 0.16242179379965355

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
linearRegression(southern_hemisphere['Lat'],southern_hemisphere['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Southern Hemisphere:\n Cloudiness vs. Latitude Linear Regression (03/31/20)")
plt.ylim(0,100)
plt.savefig("../output_data/figure10.png")
plt.show()
# Out:
# The r-squared is: 0.30087080491799817

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(northern_hemisphere['Lat'],northern_hemisphere['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Northern Hemisphere:\n Wind Speed vs. Latitude Linear Regression (03/31/20)")
plt.savefig("../output_data/figure11.png")
plt.show()
# Out:
# The r-squared is: 0.20713143587765126

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
linearRegression(southern_hemisphere['Lat'],southern_hemisphere['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Southern Hemisphere:\n Wind Speed vs. Latitude Linear Regression (03/31/20)")
plt.savefig("../output_data/figure12.png")
plt.show()
# Out:
# The r-squared is: -0.2987550930039398
